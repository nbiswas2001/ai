# %%
import sympy as sym
x = sym.symbols('x')
f1 = x**2
sym.plot(f1)

# %%
sym.sqrt(8)
# Out:
# 2*sqrt(2)

# %%
x, y = sym.symbols('x y')
f2 = x + 2*y
f2
# Out:
# x + 2*y

# %%
M = sym.Matrix(3,3, [1,2,3,4,5,6,5,2,1])
M
# Out:
# Matrix([
# [1, 2, 3],
# [4, 5, 6],
# [5, 2, 1]])

# %%
InvM = M.inv()
InvM
# Out:
# Matrix([
# [  7/6, -2/3, 1/2],
# [-13/3,  7/3,  -1],
# [ 17/6, -4/3, 1/2]])
